# %%
import os

print(os.getcwd())
# Out:
# C:\Users\user\OneDrive\Desktop\Projects\BrainTumorDetection_MRI_Analysis_Model-main

# %%
import os

print(os.listdir())
# Out:
# ['.ipynb_checkpoints', 'cnnModel (1) (1).ipynb', 'no', 'program', 'README.md', 'train model', 'Untitled.ipynb', 'venv', 'yes']

# %%
import os
print(os.getcwd())
# Out:
# C:\Users\user\OneDrive\Desktop\Projects\BrainTumorDetection_MRI_Analysis_Model-main

# %%
import os

print(os.listdir())
# Out:
# ['.ipynb_checkpoints', 'cnnModel (1) (1).ipynb', 'no', 'program', 'README.md', 'train model', 'Untitled.ipynb', 'venv', 'yes']

# %%
import os

for file in os.listdir():
    print(file)
# Out:
# .ipynb_checkpoints
# cnnModel (1) (1).ipynb
# no
# program
# README.md
# train model
# Untitled.ipynb
# venv
# yes
